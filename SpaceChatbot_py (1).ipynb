# %%
# Install required libraries

import os
import google.generativeai as genai
import torch
import random
import sys
from diffusers import DiffusionPipeline
from IPython.display import display
from PIL import Image

# Set your Gemini API key directly here
GEMINI_API_KEY = "YOUR_API_KEY"
  # 🔴 Replace with your actual API key

# Configure Gemini API
genai.configure(api_key=GEMINI_API_KEY)

generation_config = {
    "temperature": 1,
    "top_p": 0.95,
    "top_k": 40,
    "max_output_tokens": 8192,
    "response_mime_type": "text/plain",
}

model = genai.GenerativeModel(
    model_name="gemini-2.0-flash",
    generation_config=generation_config,
    system_instruction="You are an expert AstroPhysicist. Provide concise, correct solutions with strategic topics about cosmology, theorems, and problems. Always respond in English.",
)

# Check for GPU availability
device = "cuda" if torch.cuda.is_available() else "gpu+-"
print(f"Using device: {device}")

# Load Stable Diffusion Model
pipe = DiffusionPipeline.from_pretrained(
    "stabilityai/stable-diffusion-xl-base-1.0",
    torch_dtype=torch.float16 if device == "cuda" else torch.float32,
    use_safetensors=True,
    variant="fp16",
).to(device)

# Function to generate an image
def generate_image(prompt):
    seed = random.randint(0, sys.maxsize)
    generator = torch.Generator(device).manual_seed(seed)

    images = pipe(
        prompt=prompt,
        output_type="pil",
        generator=generator,
    ).images

    image = images[0]

    # Resize image to 512x512 (or any desired size)
    resized_image = image.resize((512, 512), Image.LANCZOS)  # Use LANCZOS for better quality

    resized_image.save("generated_image.jpg")
    print(f"Image saved as 'generated_image.jpg' (Seed: {seed}, Size: {resized_image.size})")
    display(resized_image)  # Show in Colab

# Main execution
while True:
    user_input = input("\nAsk your question about space (or type 'exit' to quit): ").strip()
    if user_input.lower() == "exit":
        print("Exiting chatbot. Goodbye! 🚀")
        break

    # Generate text response
    response = model.generate_content(user_input)
    print("\n🤖 AI Response:\n", response.text)

    # Generate image if relevant
    if any(keyword in user_input.lower() for keyword in ["galaxy", "black hole", "nebula", "universe", "planet", "star"]):
        print("\n🖼 Generating image...")
        generate_image(user_input)
# Out:
# Using device: cuda
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Ask your question about space (or type 'exit' to quit): what is black hole
# 2025-03-11 09:55:17.218 200 POST /v1beta/models/gemini-2.0-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 5514.77ms
# 🤖 AI Response:
#  A black hole is a region in spacetime where gravity is so strong that nothing, not even light, can escape. It's essentially a point of infinite density, called a singularity, surrounded by an event horizon, which marks the "point of no return."
#
# Here's a breakdown of key concepts:
#
# ...

# %%
# !python -m streamlit run SpaaceChatbot.py
# Out:
# Usage: streamlit run [OPTIONS] TARGET [ARGS]...
# Try 'streamlit run --help' for help.
#
# Error: Invalid value: File does not exist: SpaaceChatbot.py

# %%
# !pip install diffusers
# !pip install transformers
# !pip install accelerate
# !pip install torch
# !pip install streamlit
# !pip install google-generativeai
# !pip install python-dotenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 56.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 44.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 30.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 878.0 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 90.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...
